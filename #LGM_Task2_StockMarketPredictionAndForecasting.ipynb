# %% [markdown]
# # HREEYA SINGH

# %% [markdown]
# # LGMVIP-DataScience March-2022
# ## Task2 - Stock Market Prediction and Forecasting using Stacked LSTM

# %% [markdown]
# Dataset Link: https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv

# %% [markdown]
# Import these libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import tensorflow as tf
import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , LSTM
from sklearn.metrics import mean_squared_error
# %matplotlib inline

# %% [markdown]
# Load the Data

# %%
data = pd.read_csv('NSE-TATAGLOBAL.csv')

# %%
data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
data.tail(7)
# Out:
#             Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2028  2010-07-29  112.5  121.70  112.50  117.50  116.60               2359134
# 2029  2010-07-28  118.0  120.50  117.20  118.15  118.25                835593
# 2030  2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
# 2031  2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2032  2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2033  2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2034  2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
#
#       Turnover (Lacs)
# 2028          2791.03
# 2029           994.01
# 2030           694.98
# 2031           780.01
# 2032           340.31
# 2033           355.17
# 2034           803.56

# %%
data.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %% [markdown]
# Statistical Analysis of the Data

# %%
data.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
len(data)
# Out:
# 2035

# %%
data = data.sort_values('Date')
data.head()
# Out:
#             Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034  2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
# 2033  2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2032  2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2031  2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2030  2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98

# %%
data.reset_index(inplace=True)

# %%
data_close = data['Close']
data_close
# Out:
# 0       121.55
# 1       120.90
# 2       120.65
# 3       117.60
# 4       118.65
#          ...
# 2030    233.30
# 2031    236.10
# 2032    234.25
# 2033    233.25
# 2034    233.75
# Name: Close, Length: 2035, dtype: float64

# %%
data1 = data.reset_index()['Close']

# %% [markdown]
# Data Visualization

# %%
plt.plot(data['Close'])

# %%
sns.heatmap(data.corr(), annot=True, cmap= "cubehelix_r")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Scaling Data

# %%
scaler = MinMaxScaler(feature_range=(0,1))
data_close = scaler.fit_transform(np.array(data_close).reshape(-1,1))
data_close
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        ...,
#        [0.62622549],
#        [0.62214052],
#        [0.62418301]])

# %% [markdown]
# Split the Data into train and test

# %%
training_size = int(len(data_close)*0.70)
test_size = len(data_close) - training_size
train, test = data_close[0: training_size,:], data_close[training_size : len(data_close),:1]

# %%
def create_mat(dataset, time_step = 1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step),0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = create_mat(train, time_step)
X_test, y_test = create_mat(test, time_step)

# %%
X_train.shape
# Out:
# (1323, 100)

# %%
y_train.shape
# Out:
# (1323,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# Create Stacked LSTM Model of Data

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the Model

# %%
model.fit(X_train, y_train, validation_split=0.1, epochs= 80, batch_size=64, verbose = 1)
# Out:
# Epoch 1/80
# 19/19 [==============================] - 14s 343ms/step - loss: 0.0106 - val_loss: 0.0016
# Epoch 2/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 3/80
# 19/19 [==============================] - 4s 218ms/step - loss: 9.9596e-04 - val_loss: 0.0012
# Epoch 4/80
# 19/19 [==============================] - 4s 213ms/step - loss: 8.2017e-04 - val_loss: 0.0012
# Epoch 5/80
# 19/19 [==============================] - 4s 222ms/step - loss: 8.0704e-04 - val_loss: 0.0011
# Epoch 6/80
# 19/19 [==============================] - 4s 215ms/step - loss: 7.7563e-04 - val_loss: 0.0011
# Epoch 7/80
# 19/19 [==============================] - 4s 197ms/step - loss: 7.7052e-04 - val_loss: 0.0010
# Epoch 8/80
# 19/19 [==============================] - 4s 217ms/step - loss: 8.2395e-04 - val_loss: 9.8994e-04
# Epoch 9/80
# 19/19 [==============================] - 4s 212ms/step - loss: 8.0492e-04 - val_loss: 0.0011
# Epoch 10/80
# 19/19 [==============================] - 4s 217ms/step - loss: 7.5187e-04 - val_loss: 0.0010
# Epoch 11/80
# 19/19 [==============================] - 4s 216ms/step - loss: 7.2561e-04 - val_loss: 8.8801e-04
# Epoch 12/80
# 19/19 [==============================] - 4s 220ms/step - loss: 7.1872e-04 - val_loss: 9.3260e-04
# Epoch 13/80
# 19/19 [==============================] - 4s 204ms/step - loss: 6.8656e-04 - val_loss: 8.3489e-04
# Epoch 14/80
# 19/19 [==============================] - 4s 221ms/step - loss: 6.6004e-04 - val_loss: 8.0314e-04
# Epoch 15/80
# 19/19 [==============================] - 4s 218ms/step - loss: 6.3096e-04 - val_loss: 7.7759e-04
# Epoch 16/80
# 19/19 [==============================] - 4s 209ms/step - loss: 1.9892e-04 - val_loss: 1.7150e-04
# Epoch 70/80
# 19/19 [==============================] - 4s 214ms/step - loss: 1.9010e-04 - val_loss: 1.9845e-04
# Epoch 71/80
# 19/19 [==============================] - 4s 221ms/step - loss: 2.0753e-04 - val_loss: 1.9022e-04
# Epoch 72/80
# 19/19 [==============================] - 4s 213ms/step - loss: 2.0502e-04 - val_loss: 1.7491e-04
# Epoch 73/80
# 19/19 [==============================] - 4s 210ms/step - loss: 1.9533e-04 - val_loss: 1.6675e-04
# Epoch 74/80
# 19/19 [==============================] - 4s 198ms/step - loss: 1.8422e-04 - val_loss: 1.5519e-04
# Epoch 75/80
# 19/19 [==============================] - 4s 210ms/step - loss: 1.8116e-04 - val_loss: 1.5043e-04
# Epoch 76/80
# 19/19 [==============================] - 4s 215ms/step - loss: 1.7951e-04 - val_loss: 1.5287e-04
# Epoch 77/80
# 19/19 [==============================] - 4s 213ms/step - loss: 2.2265e-04 - val_loss: 2.9843e-04
# Epoch 78/80
# 19/19 [==============================] - 4s 219ms/step - loss: 1.9926e-04 - val_loss: 2.5044e-04
# Epoch 79/80
# 19/19 [==============================] - 4s 200ms/step - loss: 2.3217e-04 - val_loss: 2.2063e-04
# Epoch 80/80
# 19/19 [==============================] - 4s 212ms/step - loss: 1.8353e-04 - val_loss: 2.2246e-04

# %% [markdown]
# Prediction and Checking Part

# %%
predictions = model.predict(X_test)

# %%
inv_predictions = scaler.inverse_transform(predictions)

# %%
inv_predictions
# Out:
# array([[144.28905 ],
#        [144.40997 ],
#        [143.14877 ],
#        [139.88127 ],
#        [138.6262  ],
#        [138.61876 ],
#        [140.42166 ],
#        [142.07826 ],
#        [141.89865 ],
#        [141.12158 ],
#        [140.92915 ],
#        [142.70819 ],
#        [143.44766 ],
#        [145.23482 ],
#        [147.64218 ],
#        [144.09761 ],
#        [141.4236  ],
#        [141.96915 ],
#        [143.14746 ],
#        [149.6799  ],
#        [153.81488 ],
#        [154.80798 ],
#        [154.31927 ],
#        [151.52596 ],
#        [152.20967 ],
#        [152.27893 ],
#        [152.92719 ],
#        [155.01616 ],
#        [155.33946 ],
#        [154.9515  ],
#        [155.45232 ],
#        [153.82738 ],
#        [149.91087 ],
#        [143.52739 ],
#        [141.00008 ],
#        [140.98326 ],
#        [141.46545 ],
#        [140.13493 ],
#        [137.1097  ],
#        [132.90158 ],
#        [130.79065 ],
#        [130.16066 ],
#        [127.82637 ],
#        [127.29253 ],
#        [124.865814],
#        [121.93873 ],
#        [121.805305],
#        [121.73882 ],
#        [122.131905],
#        [120.735306],
#        [119.7189  ],
#        [119.4356  ],
#        [118.51175 ],
#        [118.90572 ],
#        [120.677345],
#        [122.65212 ],
#        [124.57908 ],
#        [124.858376],
#        [124.124344],
#        [124.16916 ],
#        [124.46081 ],
#        [124.25316 ],
#        [124.57463 ],
#        [125.07416 ],
#        [125.224915],
#        [125.193855],
#        [124.90144 ],
#        [125.35485 ],
#        [125.902534],
#        [126.23486 ],
#        [125.08026 ],
#        [123.96145 ],
#        [122.514465],
#        [121.32187 ],
#        [120.02906 ],
#        [120.62383 ],
#        [121.431786],
#        [122.50493 ],
#        [123.59813 ],
#        [124.833145],
#        [125.9398  ],
#        [126.46682 ],
#        [126.791695],
#        [126.65575 ],
#        [126.41501 ],
#        [126.13257 ],
#        [127.275375],
#        [127.55023 ],
#        [128.66156 ],
#        [129.42188 ],
#        [129.65727 ],
#        [130.05577 ],
#        [131.18172 ],
#        [130.31989 ],
#        [129.66211 ],
#        [129.72685 ],
#        [130.01788 ],
#        [130.63522 ],
#        [131.6758  ],
#        [131.72182 ],
#        [131.87646 ],
#        [135.41512 ],
#        [140.68999 ],
#        [144.47595 ],
#        [145.14656 ],
#        [146.43025 ],
#        [146.22873 ],
#        [145.50366 ],
#        [144.0411  ],
#        [142.78159 ],
#        [141.1875  ],
#        [141.07324 ],
#        [141.74666 ],
#        [143.1544  ],
#        [144.1904  ],
#        [143.77374 ],
#        [142.6472  ],
#        [141.65822 ],
#        [140.78069 ],
#        [143.04666 ],
#        [144.14546 ],
#        [145.22633 ],
#        [145.72801 ],
#        [145.4502  ],
#        [144.32259 ],
#        [143.15804 ],
#        [140.78882 ],
#        [140.37418 ],
#        [141.66609 ],
#        [144.81258 ],
#        [147.13638 ],
#        [148.72044 ],
#        [148.90245 ],
#        [146.97653 ],
#        [149.58    ],
#        [152.31789 ],
#        [152.14441 ],
#        [152.0405  ],
#        [152.14427 ],
#        [152.0274  ],
#        [152.14119 ],
#        [153.05817 ],
#        [154.21683 ],
#        [155.06773 ],
#        [154.048   ],
#        [153.14052 ],
#        [154.14418 ],
#        [154.38899 ],
#        [153.52861 ],
#        [152.24857 ],
#        [150.88063 ],
#        [151.33841 ],
#        [153.25505 ],
#        [154.16614 ],
#        [154.52356 ],
#        [154.34848 ],
#        [155.13333 ],
#        [154.89284 ],
#        [154.89577 ],
#        [157.4949  ],
#        [158.72829 ],
#        [158.22557 ],
#        [155.7634  ],
#        [154.22446 ],
#        [154.72314 ],
#        [156.11678 ],
#        [156.60907 ],
#        [155.8124  ],
#        [156.1218  ],
#        [156.58032 ],
#        [155.90598 ],
#        [152.31528 ],
#        [150.8443  ],
#        [150.10027 ],
#        [148.39113 ],
#        [145.75136 ],
#        [144.96268 ],
#        [147.24571 ],
#        [148.64171 ],
#        [148.93852 ],
#        [150.62672 ],
#        [153.42369 ],
#        [156.25919 ],
#        [157.45792 ],
#        [156.21465 ],
#        [156.12619 ],
#        [155.99878 ],
#        [155.80023 ],
#        [154.52931 ],
#        [156.07086 ],
#        [158.97829 ],
#        [161.09941 ],
#        [161.24355 ],
#        [159.62198 ],
#        [158.59627 ],
#        [158.35646 ],
#        [157.38724 ],
#        [154.78926 ],
#        [151.16617 ],
#        [150.31003 ],
#        [150.61871 ],
#        [152.29897 ],
#        [154.07764 ],
#        [154.02844 ],
#        [156.54002 ],
#        [156.99406 ],
#        [158.63321 ],
#        [164.61311 ],
#        [170.28865 ],
#        [174.7357  ],
#        [176.88293 ],
#        [175.99007 ],
#        [176.24788 ],
#        [174.74123 ],
#        [174.56642 ],
#        [172.81645 ],
#        [172.48262 ],
#        [171.76556 ],
#        [172.28497 ],
#        [173.6924  ],
#        [172.22481 ],
#        [171.23999 ],
#        [171.29245 ],
#        [170.31735 ],
#        [168.12234 ],
#        [167.83606 ],
#        [168.20877 ],
#        [170.89813 ],
#        [169.97426 ],
#        [166.02853 ],
#        [160.03267 ],
#        [161.81345 ],
#        [173.67014 ],
#        [191.04245 ],
#        [197.05208 ],
#        [196.98929 ],
#        [195.70114 ],
#        [190.12822 ],
#        [191.44525 ],
#        [192.55243 ],
#        [192.45485 ],
#        [190.56432 ],
#        [194.43008 ],
#        [198.15477 ],
#        [198.93211 ],
#        [195.31415 ],
#        [195.32634 ],
#        [202.6619  ],
#        [206.48956 ],
#        [207.03993 ],
#        [207.69783 ],
#        [209.5747  ],
#        [206.67853 ],
#        [207.99565 ],
#        [208.42087 ],
#        [210.28241 ],
#        [213.3167  ],
#        [212.47157 ],
#        [210.07515 ],
#        [201.01598 ],
#        [194.16882 ],
#        [199.20259 ],
#        [199.60887 ],
#        [201.92517 ],
#        [205.06155 ],
#        [206.2761  ],
#        [204.62274 ],
#        [206.31798 ],
#        [207.46979 ],
#        [206.4227  ],
#        [205.62192 ],
#        [206.19273 ],
#        [208.62085 ],
#        [208.49463 ],
#        [207.35312 ],
#        [207.3935  ],
#        [205.20866 ],
#        [202.59914 ],
#        [200.96613 ],
#        [205.69577 ],
#        [205.54286 ],
#        [207.39511 ],
#        [216.04268 ],
#        [224.18181 ],
#        [225.41829 ],
#        [223.82564 ],
#        [221.14273 ],
#        [219.25552 ],
#        [226.27228 ],
#        [222.70477 ],
#        [219.18234 ],
#        [230.98216 ],
#        [233.72485 ],
#        [230.29118 ],
#        [237.48653 ],
#        [244.05379 ],
#        [245.14835 ],
#        [249.68724 ],
#        [262.20752 ],
#        [263.60403 ],
#        [261.02136 ],
#        [259.85107 ],
#        [262.83075 ],
#        [262.90674 ],
#        [270.71307 ],
#        [266.6703  ],
#        [269.24588 ],
#        [267.55258 ],
#        [262.45715 ],
#        [262.18423 ],
#        [258.98364 ],
#        [265.8204  ],
#        [271.85452 ],
#        [279.62082 ],
#        [270.9915  ],
#        [263.52136 ],
#        [262.99744 ],
#        [266.58154 ],
#        [271.23172 ],
#        [279.7764  ],
#        [280.77435 ],
#        [277.98584 ],
#        [278.61075 ],
#        [281.48773 ],
#        [281.48383 ],
#        [281.71423 ],
#        [289.7255  ],
#        [288.29315 ],
#        [284.6578  ],
#        [284.007   ],
#        [285.32236 ],
#        [286.33774 ],
#        [290.1548  ],
#        [288.6179  ],
#        [286.30923 ],
#        [285.2614  ],
#        [295.62387 ],
#        [295.34354 ],
#        [287.47726 ],
#        [283.44388 ],
#        [277.30148 ],
#        [279.96005 ],
#        [282.5467  ],
#        [281.4688  ],
#        [278.3332  ],
#        [277.7968  ],
#        [276.11945 ],
#        [277.75952 ],
#        [267.17197 ],
#        [263.09918 ],
#        [253.24738 ],
#        [251.38148 ],
#        [248.42563 ],
#        [260.05084 ],
#        [264.18173 ],
#        [260.79263 ],
#        [264.1399  ],
#        [262.4923  ],
#        [258.6356  ],
#        [255.21506 ],
#        [249.12498 ],
#        [244.75537 ],
#        [248.89937 ],
#        [248.05952 ],
#        [254.4651  ],
#        [258.88248 ],
#        [259.669   ],
#        [258.86118 ],
#        [257.43045 ],
#        [257.6038  ],
#        [256.74335 ],
#        [252.33551 ],
#        [255.3957  ],
#        [253.36038 ],
#        [258.76004 ],
#        [262.5931  ],
#        [262.5652  ],
#        [262.32187 ],
#        [255.93385 ],
#        [244.28812 ],
#        [244.2513  ],
#        [248.29369 ],
#        [246.56905 ],
#        [244.87817 ],
#        [248.34663 ],
#        [250.90718 ],
#        [246.57762 ],
#        [259.10025 ],
#        [261.84348 ],
#        [255.62578 ],
#        [255.09422 ],
#        [255.80705 ],
#        [260.3902  ],
#        [259.9131  ],
#        [257.53528 ],
#        [257.05087 ],
#        [258.84692 ],
#        [262.9393  ],
#        [264.73227 ],
#        [266.70743 ],
#        [268.2111  ],
#        [267.85062 ],
#        [264.87488 ],
#        [263.67166 ],
#        [268.93582 ],
#        [272.2904  ],
#        [272.69638 ],
#        [276.2983  ],
#        [272.69327 ],
#        [265.6463  ],
#        [265.73886 ],
#        [272.68954 ],
#        [270.81412 ],
#        [270.9272  ],
#        [265.5191  ],
#        [265.99747 ],
#        [240.22354 ],
#        [223.85324 ],
#        [225.17091 ],
#        [235.42975 ],
#        [237.2815  ],
#        [235.04308 ],
#        [236.37193 ],
#        [239.02777 ],
#        [242.4227  ],
#        [245.1583  ],
#        [247.11702 ],
#        [244.31914 ],
#        [248.44792 ],
#        [254.28188 ],
#        [250.55785 ],
#        [241.68141 ],
#        [247.07614 ],
#        [252.72983 ],
#        [254.75252 ],
#        [254.1155  ],
#        [250.58688 ],
#        [252.62892 ],
#        [255.53636 ],
#        [262.50082 ],
#        [259.14972 ],
#        [258.8734  ],
#        [252.36905 ],
#        [245.38986 ],
#        [243.0588  ],
#        [247.66737 ],
#        [252.00774 ],
#        [254.80531 ],
#        [253.02606 ],
#        [250.03288 ],
#        [253.53731 ],
#        [251.00447 ],
#        [262.78506 ],
#        [263.7692  ],
#        [256.07336 ],
#        [249.35745 ],
#        [256.53696 ],
#        [259.87476 ],
#        [255.49498 ],
#        [249.88184 ],
#        [244.0982  ],
#        [230.94885 ],
#        [233.10352 ],
#        [229.79532 ],
#        [224.51259 ],
#        [228.45699 ],
#        [234.8659  ],
#        [238.49474 ],
#        [230.46129 ],
#        [227.97246 ],
#        [231.13919 ],
#        [232.81435 ],
#        [236.55154 ],
#        [228.77124 ],
#        [224.96837 ],
#        [225.05878 ],
#        [230.13919 ],
#        [231.0163  ],
#        [229.346   ],
#        [229.26765 ],
#        [226.62407 ],
#        [226.41487 ],
#        [229.41357 ],
#        [232.10385 ],
#        [235.25494 ],
#        [237.34537 ],
#        [233.4761  ],
#        [227.25829 ],
#        [222.39395 ],
#        [227.08313 ],
#        [227.60722 ],
#        [227.9566  ],
#        [229.26793 ],
#        [228.26364 ],
#        [229.26694 ],
#        [219.61162 ],
#        [214.6423  ],
#        [214.2251  ],
#        [217.05074 ],
#        [218.038   ],
#        [213.39581 ],
#        [216.2031  ],
#        [226.9798  ],
#        [232.78807 ],
#        [230.87788 ],
#        [227.90579 ],
#        [226.45155 ],
#        [225.43106 ],
#        [227.74185 ],
#        [227.8294  ]], dtype=float32)

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
#Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %% [markdown]
# Calculate RootMeanSquare Error of the model

# %%
MSE = math.sqrt(mean_squared_error(y_test, predictions))
print("The MSE for above model is: ", MSE)
# Out:
# The MSE for above model is:  0.048274391317552755

# %%
math.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 0.048274391317552755

# %% [markdown]
# Plotting

# %%
# shift train predictions for plotting
look_back=100
trainPredictPlot = np.empty_like(data_close)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict

# shift test predictions for plotting
testPredictPlot = np.empty_like(data_close)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(data1)-1, :] = test_predict

# plot baseline and predictions
plt.plot(scaler.inverse_transform(data_close))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
temp_input=list(X_test)
temp_input=temp_input[0].tolist()
temp_input
# Out:
# [[0.16217320261437906],
#  [0.15951797385620914],
#  [0.16707516339869277],
#  [0.15992647058823523],
#  [0.1605392156862745],
#  [0.16441993464052285],
#  [0.1668709150326797],
#  [0.16932189542483655],
#  [0.16074346405228757],
#  [0.1597222222222222],
#  [0.1640114379084967],
#  [0.15727124183006536],
#  [0.14705882352941174],
#  [0.14460784313725483],
#  [0.15175653594771238],
#  [0.15441176470588236],
#  [0.15216503267973858],
#  [0.14848856209150324],
#  [0.15522875816993464],
#  [0.1576797385620915],
#  [0.16217320261437906],
#  [0.16094771241830064],
#  [0.1633986928104575],
#  [0.15931372549019607],
#  [0.1597222222222222],
#  [0.1611519607843137],
#  [0.16666666666666663],
#  [0.15747549019607843],
#  [0.1537990196078431],
#  [0.14848856209150324],
#  [0.15114379084967322],
#  [0.15032679738562088],
#  [0.1515522875816993],
#  [0.15645424836601307],
#  [0.16033496732026142],
#  [0.1566584967320261],
#  [0.15686274509803916],
#  [0.1774918300653595],
#  [0.1797385620915033],
#  [0.17442810457516345],
#  [0.19281045751633985],
#  [0.1860702614379085],
#  [0.1881127450980392],
#  [0.18443627450980393],
#  [0.18280228758169936],
#  [0.184640522875817],
#  [0.181781045751634],
#  [0.18913398692810457],
#  [0.18709150326797386],
#  [0.1768790849673203],
#  [0.18382352941176472],
#  [0.19158496732026142],
#  [0.19914215686274506],
#  [0.2052696078431372],
#  [0.22038398692810457],
#  [0.21711601307189543],
#  [0.21629901960784315],
#  [0.21854575163398682],
#  [0.21098856209150318],
#  [0.2130310457516339],
#  [0.21221405228758172],
#  [0.20915032679738566],
#  [0.21098856209150318],
#  [0.21098856209150318],
#  [0.2001633986928104],
#  [0.20057189542483667],
#  [0.21609477124183007],
#  [0.20772058823529416],
#  [0.20649509803921562],
#  [0.2144607843137254],
#  [0.20506535947712423],
#  [0.2308006535947712],
#  [0.24183006535947715],
#  [0.25],
#  [0.24530228758169936],
#  [0.23468137254901966],
#  [0.22385620915032678],
#  [0.23427287581699352],
#  [0.23754084967320255],
#  [0.25306372549019607],
#  [0.25449346405228757],
#  [0.23202614379084963],
#  [0.2301879084967321],
#  [0.2287581699346405],
#  [0.23325163398692816],
#  [0.23161764705882348],
#  [0.2365196078431372],
#  [0.24632352941176472],
#  [0.23468137254901966],
#  [0.23958333333333326],
#  [0.2422385620915033],
#  [0.24305555555555547],
#  [0.2408088235294118],
#  [0.2371323529411764],
#  [0.2420343137254901],
#  [0.2422385620915033],
#  [0.2457107843137255],
#  [0.24775326797385622],
#  [0.24836601307189543],
#  [0.25020424836601296]]
