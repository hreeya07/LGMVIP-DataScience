# %% [markdown]
# # HREEYA SINGH

# %% [markdown]
# # LGMVIP - DataScience Intern, March-2022
# ## Task6 - Exploratory Data Analysis on Dataset - Terrorism
# ### Intermediate Level Task
# Dataset Link: https://bit.ly/2TK5Xn5

# %% [markdown]
# Import these libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("global_terrorism.csv", encoding = "ISO-8859-1")
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]

# %%
df.head(7)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# 2         Philippines       5  ...
# 3              Greece       8  ...
# 4               Japan       4  ...
# 5       United States       1  ...
# 6             Uruguay       3  ...
#
#                                             addnotes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  The Cairo Chief of Police, William Petersen, r...
# 6                                                NaN
#
#                                               scite1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  "Police Chief Quits," Washington Post, January...
# 6                                                NaN
#
#                                               scite2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  "Cairo Police Chief Quits; Decries Local 'Mili...
# 6                                                NaN
#
#                                               scite3        dbsource  INT_LOG  \
# 0                                                NaN            PGIS        0
# 1                                                NaN            PGIS        0
# 2                                                NaN            PGIS       -9
# 3                                                NaN            PGIS       -9
# 4                                                NaN            PGIS       -9
# 5  Christopher Hewitt, "Political Violence and Te...  Hewitt Project       -9
# 6                                                NaN            PGIS        0
#
#    INT_IDEO INT_MISC INT_ANY  related
# 0         0        0       0      NaN
# 1         1        1       1      NaN
# 2        -9        1       1      NaN
# 3        -9        1       1      NaN
# 4        -9        1       1      NaN
# 5        -9        0      -9      NaN
# 6         0        0       0      NaN
#
# [7 rows x 135 columns]

# %%
df.tail(3)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  scite3  \
# 181688                                                NaN     NaN
# 181689                                                NaN     NaN
# 181690  "Security tightened in Cotabato City," Manila ...     NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [3 rows x 135 columns]

# %% [markdown]
# ## Checking all column names

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %% [markdown]
# ## Statistic analysis of datasets

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.describe(include="all")
# Out:
#              eventid          iyear         imonth           iday  \
# count   1.816910e+05  181691.000000  181691.000000  181691.000000
# unique           NaN            NaN            NaN            NaN
# top              NaN            NaN            NaN            NaN
# freq             NaN            NaN            NaN            NaN
# mean    2.002705e+11    2002.638997       6.467277      15.505644
# std     1.325957e+09      13.259430       3.388303       8.814045
# min     1.970000e+11    1970.000000       0.000000       0.000000
# 25%     1.991021e+11    1991.000000       4.000000       8.000000
# 50%     2.009022e+11    2009.000000       6.000000      15.000000
# 75%     2.014081e+11    2014.000000       9.000000      23.000000
# max     2.017123e+11    2017.000000      12.000000      31.000000
#
#                    approxdate       extended resolution        country  \
# count                    9239  181691.000000       2220  181691.000000
# unique                   2244            NaN       1859            NaN
# top     September 18-24, 2016            NaN   8/4/1998            NaN
# freq                      101            NaN         18            NaN
# mean                      NaN       0.045346        NaN     131.968501
# std                       NaN       0.208063        NaN     112.414535
# min                       NaN       0.000000        NaN       4.000000
# 25%                       NaN       0.000000        NaN      78.000000
# 50%                       NaN       0.000000        NaN      98.000000
# 75%                       NaN       0.000000        NaN     160.000000
# max                       NaN       1.000000        NaN    1004.000000
#
#        country_txt         region  ...  \
# count       181691  181691.000000  ...
# unique         205            NaN  ...
# top           Iraq            NaN  ...
# freq         24636            NaN  ...
# mean           NaN       7.160938  ...
# std            NaN       2.933408  ...
# min            NaN       1.000000  ...
# 25%            NaN       5.000000  ...
# 50%            NaN       6.000000  ...
# 75%            NaN      10.000000  ...
# max            NaN      12.000000  ...
#
#                                                  addnotes  \
# count                                               28289
# unique                                              15429
# top     Casualty numbers for this incident conflict ac...
# freq                                                 1607
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    scite1  \
# count                                              115500
# unique                                              83988
# top     Committee on Government Operations United Stat...
# freq                                                  205
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    scite2  \
# count                                               76933
# unique                                              62263
# top     Christopher Hewitt, "Political Violence and Te...
# freq                                                  134
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    scite3  \
# count                                               43516
# unique                                              36090
# top     Christopher Hewitt, "Political Violence and Te...
# freq                                                  139
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                         dbsource        INT_LOG       INT_IDEO       INT_MISC  \
# count                     181691  181691.000000  181691.000000  181691.000000
# unique                        26            NaN            NaN            NaN
# top     START Primary Collection            NaN            NaN            NaN
# freq                       78002            NaN            NaN            NaN
# mean                         NaN      -4.543731      -4.464398       0.090010
# std                          NaN       4.543547       4.637152       0.568457
# min                          NaN      -9.000000      -9.000000      -9.000000
# 25%                          NaN      -9.000000      -9.000000       0.000000
# 50%                          NaN      -9.000000      -9.000000       0.000000
# 75%                          NaN       0.000000       0.000000       0.000000
# max                          NaN       1.000000       1.000000       1.000000
#
#               INT_ANY                                            related
# count   181691.000000                                              25038
# unique            NaN                                              14306
# top               NaN  201612010023, 201612010024, 201612010025, 2016...
# freq              NaN                                                 80
# mean        -3.945952                                                NaN
# std          4.691325                                                NaN
# min         -9.000000                                                NaN
# 25%         -9.000000                                                NaN
# 50%          0.000000                                                NaN
# 75%          0.000000                                                NaN
# max          1.000000                                                NaN
#
# [11 rows x 135 columns]

# %%
df.shape
# Out:
# (181691, 135)

# %%
def missing(dff):
    print(round((dff.isnull().sum() * 100/ len(dff)),2).sort_values(ascending=False))
missing(df)
# Out:
# gsubname3           99.99
# weaptype4           99.96
# weaptype4_txt       99.96
# weapsubtype4        99.96
# weapsubtype4_txt    99.96
#                     ...
# multiple             0.00
# doubtterr            0.00
# crit3                0.00
# property             0.00
# eventid              0.00
# Length: 135, dtype: float64

# %% [markdown]
# Deleting all those columns where missing percentage of data is higher than 80%

# %%
limitPer = len(df) * .80
df = df.dropna(thresh=limitPer, axis=1)
df.shape
# Out:
# (181691, 47)

# %% [markdown]
# Remaining columns in dataframe

# %%
col=df.columns
data=pd.DataFrame(df, columns=col)
data.head()
# Out:
#         eventid  iyear  imonth  iday  extended  country         country_txt  \
# 0  197000000001   1970       7     2         0       58  Dominican Republic
# 1  197000000002   1970       0     0         0      130              Mexico
# 2  197001000001   1970       1     0         0      160         Philippines
# 3  197001000002   1970       1     0         0       78              Greece
# 4  197001000003   1970       1     0         0      101               Japan
#
#    region                   region_txt provstate  ...        weapsubtype1_txt  \
# 0       2  Central America & Caribbean       NaN  ...                     NaN
# 1       1                North America   Federal  ...                     NaN
# 2       5               Southeast Asia    Tarlac  ...                     NaN
# 3       8               Western Europe    Attica  ...  Unknown Explosive Type
# 4       4                    East Asia   Fukouka  ...                     NaN
#
#    nkill  nwound  property  ishostkid  dbsource  INT_LOG  INT_IDEO  INT_MISC  \
# 0    1.0     0.0         0        0.0      PGIS        0         0         0
# 1    0.0     0.0         0        1.0      PGIS        0         1         1
# 2    1.0     0.0         0        0.0      PGIS       -9        -9         1
# 3    NaN     NaN         1        0.0      PGIS       -9        -9         1
# 4    NaN     NaN         1        0.0      PGIS       -9        -9         1
#
#    INT_ANY
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#
# [5 rows x 47 columns]

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'extended', 'country',
#        'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude',
#        'longitude', 'specificity', 'vicinity', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'multiple', 'success', 'suicide', 'attacktype1',
#        'attacktype1_txt', 'targtype1', 'targtype1_txt', 'targsubtype1',
#        'targsubtype1_txt', 'target1', 'natlty1', 'natlty1_txt', 'gname',
#        'guncertain1', 'individual', 'weaptype1', 'weaptype1_txt',
#        'weapsubtype1', 'weapsubtype1_txt', 'nkill', 'nwound', 'property',
#        'ishostkid', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY'],
#       dtype='object')

# %% [markdown]
# ## Read the datasets

# %%
print("Maximum Terrorism attacked on Country         :", df["country_txt"].value_counts().idxmax())
print("City most attacked by Terrosist               :",df['city'].value_counts().index[1])
print("Highly Terrorism Region                       :", df["region_txt"].value_counts().index[0])
print("Year on which maximum terrorism occured       :", df["iyear"].value_counts().idxmax())
print("Month on which maximum attacks are done       :",df['imonth'].value_counts().idxmax())
print("Day on which maximum terrirsm attack are done :",df['iday'].value_counts().idxmax())
print("Group with the most attacks                   :",df['gname'].value_counts().index[1])
print("Most Attack Types                             :",df['attacktype1_txt'].value_counts().idxmax())
print("Most Target Types                             :",df['targtype1_txt'].value_counts().idxmax())
print("Successful Terrorist attack                   :",df["success"].value_counts().sum())
# Out:
# Maximum Terrorism attacked on Country         : Iraq
# City most attacked by Terrosist               : Baghdad
# Highly Terrorism Region                       : Middle East & North Africa
# Year on which maximum terrorism occured       : 2014
# Month on which maximum attacks are done       : 5
# Day on which maximum terrirsm attack are done : 15
# Group with the most attacks                   : Taliban
# Most Attack Types                             : Bombing/Explosion
# Most Target Types                             : Private Citizens & Property
# Successful Terrorist attack                   : 181691

# %% [markdown]
# ## EDA

# %%
plt.figure(figsize=(16,7))
plt.title("Count of Terrorist Attack in Years", size=20)
plt.xlabel("Attack Years",size=15)
plt.ylabel("Number of attacks each year", size=15)
plt.xticks(data['iyear'].unique(), rotation=45)
plt.grid()
sns.lineplot(x=data['iyear'].unique(), y=data['iyear'].value_counts(dropna=False).sort_index(),color='red')
plt.show()

# %% [markdown]
# ### The highest count of terrorist attack was in year 2014.

# %%
plt.figure(figsize=(15,6))

sns.countplot(data=data, x=data["region_txt"], palette='Set2')
plt.xticks(rotation=45)
plt.xlabel("Region",  size=13, fontweight="bold"  )
plt.ylabel("Count",  size=13, fontweight="bold" )
plt.title("count of attack on various regions in the world ", fontweight="bold" ,  size=25)
plt.show()

# %% [markdown]
# ### The most targeted region is "Middle East and North Africa". The safest region in world from these terrorist attacks is "Australasia & Oceania" and "Central Asia"

# %%
plt.subplots(figsize=(14,6))
sns.countplot('city',data=df,order= df['city'].value_counts().index[1:10])
plt.xticks(rotation=90)
plt.xlabel("City")
plt.title(' Maximum Number Of Terrorist Activities By City')
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.countplot(data=data, x='attacktype1_txt', hue='success',palette='flare' , edgecolor=sns.color_palette('dark',5))
plt.xticks(rotation=45)
plt.title("Types of attacks and their success and failures", size=25, fontweight="bold")
plt.xlabel("Attack Type",  size=15, fontweight="bold" )
plt.ylabel("Count",  size=15, fontweight="bold" )
plt.show()

# %% [markdown]
# ### Over the years the most common type of terrorist attack was Bombing/Explosion with a high success rate
# ### Hostage Taking and Kidnapping, Unarmed Assult was the terrorist activity eith lowest failure rate

# %%
data['targtype1_txt'].value_counts().plot(kind='pie',figsize=[15,11],autopct='%1.1f%%')
sns.color_palette='rainbow'
plt.title('Common Targets', size=25, fontweight="bold");
plt.ylabel("Target type" ,  size=15, fontweight="bold" )
# Out:
# Text(0, 0.5, 'Target type')

# %% [markdown]
# ### The comman aim/ target of these attacks are
# 1. Civilians
# 2. Police and army

# %%
attacks = data.country_txt.value_counts()[:25].to_frame()
attacks.columns = ['Attacks']

# %%
kills = data.groupby(['country_txt'])['nkill'].sum().sort_values(ascending =False).to_frame()

# %%
attacks.merge(kills, how = 'left' , left_index = True, right_index = True).plot(kind ='bar', 
                                                                                width = 0.8 , 
                                                                                figsize=(20,6), 
                                                                                color=( 'purple', 'grey'))
plt.title("Count of on various countries and the number of casualities faced ",  size=20, fontweight="bold" )
plt.xlabel("Country",  size=15, fontweight="bold" )
plt.ylabel("Count" , size=15, fontweight="bold" )
plt.show()

# %% [markdown]
# ### Iraq is the country with the most attcks

# %% [markdown]
# The country with most attacks and killing in terrorist activities is Iraq. India is the 4th most attacked country in the world. Syria is the only country with the least attacks yet most killings

# %%
df_India= data[data['country_txt']== 'India']
df_India
# Out:
#              eventid  iyear  imonth  iday  extended  country country_txt  \
# 1186    197202220004   1972       2    22         0       92       India
# 2764    197501190004   1975       1     2         0       92       India
# 3857    197605260001   1976       5    26         0       92       India
# 5327    197709280004   1977       9    28         0       92       India
# 7337    197901130004   1979       1    13         0       92       India
# ...              ...    ...     ...   ...       ...      ...         ...
# 181663  201712300021   2017      12    30         0       92       India
# 181665  201712300023   2017      12    30         0       92       India
# 181672  201712310005   2017      12    31         0       92       India
# 181684  201712310019   2017      12    31         0       92       India
# 181689  201712310031   2017      12    31         0       92       India
#
#         region  region_txt          provstate  ...  \
# 1186         6  South Asia              Delhi  ...
# 2764         6  South Asia              Bihar  ...
# 3857         6  South Asia              Delhi  ...
# 5327         6  South Asia        Maharashtra  ...
# 7337         6  South Asia              Assam  ...
# ...        ...         ...                ...  ...
# 181663       6  South Asia             Kerala  ...
# 181665       6  South Asia       Chhattisgarh  ...
# 181672       6  South Asia  Jammu and Kashmir  ...
# 181684       6  South Asia              Assam  ...
# 181689       6  South Asia            Manipur  ...
#
#                          weapsubtype1_txt  nkill  nwound  property  ishostkid  \
# 1186               Unknown Explosive Type    0.0     0.0         0        1.0
# 2764               Unknown Explosive Type    4.0     0.0         0        0.0
# 3857               Unknown Explosive Type    0.0     0.0         1        0.0
# 5327                     Unknown Gun Type    0.0     0.0         0        1.0
# 7337    Automatic or Semi-Automatic Rifle    NaN     NaN         1        0.0
# ...                                   ...    ...     ...       ...        ...
# 181663               Other Explosive Type    0.0     0.0         0        0.0
# 181665                   Unknown Gun Type    0.0     0.0         1        0.0
# 181672                            Grenade    8.0     3.0        -9        0.0
# 181684  Automatic or Semi-Automatic Rifle    0.0     0.0         0        1.0
# 181689                            Grenade    0.0     0.0        -9        0.0
#
#                                         dbsource  INT_LOG  INT_IDEO  INT_MISC  \
# 1186                                Hijacking DB        1         1         1
# 2764    UMD Encyclopedia of World Terrorism 2012        0         0         0
# 3857                                        PGIS       -9        -9         0
# 5327                                Hijacking DB        1         1         1
# 7337                                        PGIS        0         0         0
# ...                                          ...      ...       ...       ...
# 181663                  START Primary Collection       -9        -9         0
# 181665                  START Primary Collection        0         0         0
# 181672                  START Primary Collection        1         1         0
# 181684                  START Primary Collection        0         0         0
# 181689                  START Primary Collection       -9        -9         0
#
#         INT_ANY
# 1186          1
# 2764          0
# 3857         -9
# 5327          1
# 7337          0
# ...         ...
# 181663       -9
# 181665        0
# 181672        1
# 181684        0
# 181689       -9
#
# [11960 rows x 47 columns]

# %%
plt.figure(figsize=(15,6))
sns.lineplot(data=df_India, x='iyear', y = 'nkill', hue= "attacktype1_txt")
plt.grid(axis='y')
plt.legend()
plt.title("Type of attacks over the years in India",fontweight='bold',size=20 )
plt.xlabel("Year" ,fontweight='bold',size=15)
plt.ylabel("Count of Kills",fontweight='bold',size=15)
plt.show()

# %%
plt.rcParams["figure.figsize"] = 15, 9
sns.barplot(x = data["gname"].value_counts()[1:20].index, y=data["gname"].value_counts()[1:20].values)
plt.ylabel("Total Attack" ,fontsize=15)
plt.xticks(rotation=70)
plt.xlabel("Attack Group", fontsize=15)
plt.title("Attacks Group", size=20, fontweight="bold")
plt.show()

# %%
data['gname'].value_counts()[1:11].values
# Out:
# array([7478, 5613, 4555, 3351, 3288, 2772, 2671, 2487, 2418, 2310],
#       dtype=int64)

# %%
plt.figure(figsize = (15,7))
sns.barplot(y = data['gname'].value_counts()[1:11].values, x = data['gname'].value_counts()[1:11].index,palette='rocket')
plt.title('Top 10 Terrorist Organisation with Highest Terror Attacks',size=20, fontweight="bold")
plt.ylabel('Terror Group Name',size=15, fontweight="bold")
plt.xlabel('Number of Attacks',size=15, fontweight="bold")
plt.xticks(rotation= 70)
plt.show()

# %%
plt.subplots(figsize=(15,7))
sns.countplot(df['targtype1_txt'], data=df,order= df['targtype1_txt'].value_counts().index[:5])
plt.xticks(rotation=90)
plt.xlabel("Target Type")
plt.title('Maximum Terrorism Target ')
plt.show()

# %%
Killedpeople = df[['iyear',"nkill"]].groupby(['iyear']).idxmax()
fig,axes = plt.subplots(figsize=(20,10))
c = ['red', 'yellow', 'black', 'blue', 'orange']
Killedpeople.plot(kind='bar',alpha=0.7,ax=axes,color=c)
plt.ylabel("No of people killed",fontsize=20)
plt.xlabel("Year",fontsize=20)
plt.title("Killed Graph")
# Out:
# Text(0.5, 1.0, 'Killed Graph')

# %% [markdown]
# ### Summary

# %%
print("******************************SUMMARY****************************")
print('Country with most attacks: ',data['country_txt'].value_counts().idxmax())
print('Country with least attacks: ',data['country_txt'].value_counts().idxmin())
print('City with most attacks: ',data['city'].value_counts().index[1])
print("City with least attacks:",data['city'].value_counts().idxmin())
print("Region with the most attacks:",data['region_txt'].value_counts().idxmax())
print("Region with the least attacks:",data['region_txt'].value_counts().idxmin())
print("Year with the most attacks:",data['iyear'].value_counts().idxmax())
print("Year with the least attacks:",data['iyear'].value_counts().idxmin())
print("Month with the most attacks:",data['imonth'].value_counts().idxmax())
print("Month with the least attacks:",data['imonth'].value_counts().idxmin())
print("Most active terrorist group: ",data['gname'].value_counts()[1:11].idxmax() )
print("Most common Attack Types:",data['attacktype1_txt'].value_counts().idxmax())
# Out:
# ******************************SUMMARY****************************
# Country with most attacks:  Iraq
# Country with least attacks:  South Vietnam
# City with most attacks:  Baghdad
# City with least attacks: Krpimej
# Region with the most attacks: Middle East & North Africa
# Region with the least attacks: Australasia & Oceania
# Year with the most attacks: 2014
# Year with the least attacks: 1971
# Month with the most attacks: 5
# Month with the least attacks: 0
# Most active terrorist group:  Taliban
# Most common Attack Types: Bombing/Explosion

# %% [markdown]
# ## Thank you:)
